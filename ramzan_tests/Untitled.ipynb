# %%
import torch
print(torch.cuda.is_available())
# Out:
# True

# %%
# %run train.py
# Out:
# <div class="tuneStatus">
#   <div style="display: flex;flex-direction: row">
#     <div style="display: flex;flex-direction: column;">
#       <h3>Tune Status</h3>
#       <table>
# <tbody>
# <tr><td>Current time:</td><td>2025-05-18 23:25:49</td></tr>
# <tr><td>Running for: </td><td>00:20:55.77        </td></tr>
# <tr><td>Memory:      </td><td>23.0/251.3 GiB     </td></tr>
# </tbody>
# </table>
#     </div>
#     <div class="vDivider"></div>
#     <div class="systemInfo">
#       <h3>System Info</h3>
#       Using FIFO scheduling algorithm.<br>Logical resource usage: 8.0/48 CPUs, 4.0/4 GPUs (0.0/1.0 accelerator_type:G)
#     </div>
#
#   </div>
#   <div class="hDivider"></div>
#   <div class="trialStatus">
#     <h3>Trial Status</h3>
#     <table>
# <thead>
# ...
